# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
from PIL import Image
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
torch.manual_seed(1)

# %%
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

def load_data(train_batch_size, test_batch_size):
    trainset = datasets.MNIST(root='./data', train=True, download=True,
                              transform=transforms.Compose([
                                  transforms.ToTensor(),
                                  transforms.Normalize((0.1307,), (0.3081,))
                              ]))
    train_loader = DataLoader(trainset, batch_size=train_batch_size, shuffle=True)

    testset = datasets.MNIST(root='./data', train=False, download=True,
                             transform=transforms.Compose([
                                 transforms.ToTensor(),
                                 transforms.Normalize((0.1307,), (0.3081,))
                             ]))
    test_loader = DataLoader(testset, batch_size=test_batch_size, shuffle=False)

    return train_loader, test_loader

train_batch_size = 100
test_batch_size = 100
train_loader, test_loader = load_data(train_batch_size, test_batch_size)

# %%
def load_data(train_batch_size, test_batch_size):
    # Fetch training data: total 60000 samples
        
    trainset = datasets.MNIST('data', train = True, download = False, 
                transform = transforms.Compose([
                transforms.Resize((32,32)),
                transforms.ToTensor(),
                transforms.Normalize((0.1307,), (0.3081,))
                ]))
    temp = torch.tensor(np.random.randint(0, 10, (len(trainset)),))
    trainset.targets = temp
    train_loader = torch.utils.data.DataLoader(trainset, batch_size=train_batch_size, shuffle=True)

    testset = datasets.MNIST('data', train = False, 
                transform = transforms.Compose([
                transforms.Resize((32, 32)),
                transforms.ToTensor(),
                transforms.Normalize((0.1307,), (0.3081,))
                ]))
    test_loader = torch.utils.data.DataLoader(testset ,batch_size = test_batch_size, shuffle=True)

    return (train_loader, test_loader)

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        
        self.conv1 = nn.Conv2d(1, 6, 5)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = F.max_pool2d(F.relu(self.conv1(x)), 2)
        x = F.max_pool2d(F.relu(self.conv2(x)), 2)
        # flatten as one dimension
        x = x.view(x.size()[0], -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))

        x = self.fc3(x)
        return x

# %%
train_batch_size = 100
test_batch_size = 100
train_loader, test_loader = load_data(train_batch_size, test_batch_size)

# %%
def train(model, optimizer, train_loader):
    model.train()
    correct = 0
    train_loss = 0
    counter = 0

    for batch_idx, (data, target) in enumerate(train_loader):
        counter += 1
        data, target = Variable(data), Variable(target)
        optimizer.zero_grad()

        # Forward propagation
        output = model(data)
        loss = loss_fn(output, target)
        loss.backward()
        optimizer.step()

        train_loss += loss.data

        pred = np.argmax(output.data, axis=1)
        correct += np.equal(pred, target.data).sum()
    
    train_loss = (train_loss * 100) / len(train_loader.dataset)
    acc = 100.0 * correct / len(train_loader.dataset)
    return train_loss, acc

# %%
def test(model, epoch, test_loader):
    model.eval()
    test_loss = 0
    correct = 0

    for data, target in test_loader:
        data, target = Variable(data), Variable(target)
        
        output = model(data)
        loss = loss_fn(output, target)
        test_loss += loss.data

        pred = np.argmax(output.data, axis = 1)
        correct = correct + np.equal(pred, target.data).sum()

    # Print log
    test_loss = (test_loss * 100) / len(test_loader.dataset)
    print('\nTest set, Epoch {} , Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(epoch,
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    return test_loss

# %%
model = CNN()

optimizer = optim.Adam(model.parameters(), lr=0.0001)
m1_train_loss_arr = []
m1_test_loss_arr = []

epochs = 100
log_interval = 500
loss_fn = torch.nn.CrossEntropyLoss()
for epoch in range(1, epochs + 1):
    tr_loss, acc = train(model, optimizer, train_loader)
    m1_train_loss_arr.append(tr_loss)
    loss_test = test(model, epoch, test_loader)
    m1_test_loss_arr.append(loss_test)
    print('Epoch: ', epoch)
    print('Loss= ', tr_loss)
# Out:
# Test set, Epoch 1 , Average loss: 2.3019, Accuracy: 1452/10000 (15%)
#
# Epoch:  1
# Loss=  tensor(2.3031)
#
# Test set, Epoch 2 , Average loss: 2.3015, Accuracy: 1308/10000 (13%)
#
# Epoch:  2
# Loss=  tensor(2.3023)
#
# Test set, Epoch 3 , Average loss: 2.3026, Accuracy: 1200/10000 (12%)
#
# Epoch:  3
# Loss=  tensor(2.3020)
#
# Test set, Epoch 4 , Average loss: 2.3003, Accuracy: 1255/10000 (13%)
#
# Epoch:  4
# Loss=  tensor(2.3016)
#
# Test set, Epoch 5 , Average loss: 2.2989, Accuracy: 1205/10000 (12%)
#
# Epoch:  5
# Loss=  tensor(2.3009)
#
# Test set, Epoch 6 , Average loss: 2.3013, Accuracy: 699/10000 (7%)
#
# Epoch:  6
# Loss=  tensor(2.3003)
#
# Test set, Epoch 7 , Average loss: 2.2979, Accuracy: 1205/10000 (12%)
#
# Epoch:  7
# Loss=  tensor(2.2994)
#
# Test set, Epoch 8 , Average loss: 2.3020, Accuracy: 994/10000 (10%)
#
# Epoch:  8
# Loss=  tensor(2.2982)
#
# Test set, Epoch 9 , Average loss: 2.3059, Accuracy: 1013/10000 (10%)
#
# Epoch:  9
# Loss=  tensor(2.2970)
#
# Test set, Epoch 10 , Average loss: 2.3065, Accuracy: 999/10000 (10%)
#
# Epoch:  10
# Loss=  tensor(2.2955)
#
# Test set, Epoch 11 , Average loss: 2.2967, Accuracy: 1071/10000 (11%)
#
# Epoch:  11
# Loss=  tensor(2.2938)
#
# Test set, Epoch 12 , Average loss: 2.3122, Accuracy: 854/10000 (9%)
#
# Epoch:  12
# Loss=  tensor(2.2918)
#
# Test set, Epoch 13 , Average loss: 2.2981, Accuracy: 999/10000 (10%)
#
# Epoch:  13
# Loss=  tensor(2.2898)
#
# Test set, Epoch 14 , Average loss: 2.3077, Accuracy: 1043/10000 (10%)
#
# Epoch:  14
# Loss=  tensor(2.2874)
#
# Test set, Epoch 15 , Average loss: 2.3022, Accuracy: 1200/10000 (12%)
#
# Epoch:  15
# Loss=  tensor(2.2850)
#
# Test set, Epoch 16 , Average loss: 2.2997, Accuracy: 1247/10000 (12%)
#
# Epoch:  16
# Loss=  tensor(2.2823)
#
# Test set, Epoch 17 , Average loss: 2.3062, Accuracy: 991/10000 (10%)
#
# Epoch:  17
# Loss=  tensor(2.2797)
#
# Test set, Epoch 18 , Average loss: 2.3057, Accuracy: 1059/10000 (11%)
#
# Epoch:  18
# Loss=  tensor(2.2769)
#
# Test set, Epoch 19 , Average loss: 2.3279, Accuracy: 1068/10000 (11%)
#
# Epoch:  19
# Loss=  tensor(2.2740)
#
# Test set, Epoch 20 , Average loss: 2.2917, Accuracy: 1383/10000 (14%)
#
# Epoch:  20
# Loss=  tensor(2.2701)
#
# Test set, Epoch 21 , Average loss: 2.3156, Accuracy: 1053/10000 (11%)
#
# Epoch:  21
# Loss=  tensor(2.2671)
#
# Test set, Epoch 22 , Average loss: 2.3186, Accuracy: 1070/10000 (11%)
#
# Epoch:  22
# Loss=  tensor(2.2636)
#
# Test set, Epoch 23 , Average loss: 2.3170, Accuracy: 1273/10000 (13%)
#
# Epoch:  23
# Loss=  tensor(2.2604)
#
# Test set, Epoch 24 , Average loss: 2.3340, Accuracy: 1047/10000 (10%)
#
# Epoch:  24
# Loss=  tensor(2.2570)
#
# Test set, Epoch 25 , Average loss: 2.3190, Accuracy: 1212/10000 (12%)
#
# Epoch:  25
# Loss=  tensor(2.2530)
#
# Test set, Epoch 26 , Average loss: 2.3166, Accuracy: 1196/10000 (12%)
#
# Epoch:  26
# Loss=  tensor(2.2496)
#
# Test set, Epoch 27 , Average loss: 2.3105, Accuracy: 1255/10000 (13%)
#
# Epoch:  27
# Loss=  tensor(2.2459)
#
# Test set, Epoch 28 , Average loss: 2.3326, Accuracy: 1069/10000 (11%)
#
# Epoch:  28
# Loss=  tensor(2.2418)
#
# Test set, Epoch 29 , Average loss: 2.3382, Accuracy: 1127/10000 (11%)
#
# Epoch:  29
# Loss=  tensor(2.2379)
#
# Test set, Epoch 30 , Average loss: 2.3711, Accuracy: 1010/10000 (10%)
#
# Epoch:  30
# Loss=  tensor(2.2346)
#
# Test set, Epoch 31 , Average loss: 2.3487, Accuracy: 1152/10000 (12%)
#
# Epoch:  31
# Loss=  tensor(2.2301)
#
# Test set, Epoch 32 , Average loss: 2.3309, Accuracy: 1263/10000 (13%)
#
# Epoch:  32
# Loss=  tensor(2.2264)
#
# Test set, Epoch 33 , Average loss: 2.3338, Accuracy: 1228/10000 (12%)
#
# Epoch:  33
# Loss=  tensor(2.2229)
#
# Test set, Epoch 34 , Average loss: 2.3591, Accuracy: 1178/10000 (12%)
#
# Epoch:  34
# Loss=  tensor(2.2185)
#
# Test set, Epoch 35 , Average loss: 2.3489, Accuracy: 1213/10000 (12%)
#
# Epoch:  35
# Loss=  tensor(2.2144)
#
# Test set, Epoch 36 , Average loss: 2.3682, Accuracy: 1121/10000 (11%)
#
# Epoch:  36
# Loss=  tensor(2.2108)
#
# Test set, Epoch 37 , Average loss: 2.3405, Accuracy: 1221/10000 (12%)
#
# Epoch:  37
# Loss=  tensor(2.2063)
#
# Test set, Epoch 38 , Average loss: 2.3608, Accuracy: 1198/10000 (12%)
#
# Epoch:  38
# Loss=  tensor(2.2023)
#
# Test set, Epoch 39 , Average loss: 2.3605, Accuracy: 1069/10000 (11%)
#
# Epoch:  39
# Loss=  tensor(2.1988)
#
# Test set, Epoch 40 , Average loss: 2.3148, Accuracy: 1485/10000 (15%)
#
# Epoch:  40
# Loss=  tensor(2.1945)
#
# Test set, Epoch 41 , Average loss: 2.3909, Accuracy: 1057/10000 (11%)
#
# Epoch:  41
# Loss=  tensor(2.1907)
#
# Test set, Epoch 42 , Average loss: 2.3569, Accuracy: 1242/10000 (12%)
#
# Epoch:  42
# Loss=  tensor(2.1866)
#
# Test set, Epoch 43 , Average loss: 2.3709, Accuracy: 1119/10000 (11%)
#
# Epoch:  43
# Loss=  tensor(2.1829)
#
# Test set, Epoch 44 , Average loss: 2.3751, Accuracy: 1112/10000 (11%)
#
# Epoch:  44
# Loss=  tensor(2.1779)
#
# Test set, Epoch 45 , Average loss: 2.4082, Accuracy: 1079/10000 (11%)
#
# Epoch:  45
# Loss=  tensor(2.1744)
#
# Test set, Epoch 46 , Average loss: 2.3937, Accuracy: 1048/10000 (10%)
#
# Epoch:  46
# Loss=  tensor(2.1704)
#
# Test set, Epoch 47 , Average loss: 2.3782, Accuracy: 1146/10000 (11%)
#
# Epoch:  47
# Loss=  tensor(2.1673)
#
# Test set, Epoch 48 , Average loss: 2.4116, Accuracy: 1042/10000 (10%)
#
# Epoch:  48
# Loss=  tensor(2.1617)
#
# Test set, Epoch 49 , Average loss: 2.4219, Accuracy: 981/10000 (10%)
#
# Epoch:  49
# Loss=  tensor(2.1589)
#
# Test set, Epoch 50 , Average loss: 2.4315, Accuracy: 958/10000 (10%)
#
# Epoch:  50
# Loss=  tensor(2.1541)
#
# Test set, Epoch 51 , Average loss: 2.4142, Accuracy: 1133/10000 (11%)
#
# Epoch:  51
# Loss=  tensor(2.1505)
#
# Test set, Epoch 52 , Average loss: 2.4127, Accuracy: 1033/10000 (10%)
#
# Epoch:  52
# Loss=  tensor(2.1458)
#
# Test set, Epoch 53 , Average loss: 2.4239, Accuracy: 1045/10000 (10%)
#
# Epoch:  53
# Loss=  tensor(2.1427)
#
# Test set, Epoch 54 , Average loss: 2.4452, Accuracy: 1054/10000 (11%)
#
# Epoch:  54
# Loss=  tensor(2.1377)
#
# Test set, Epoch 55 , Average loss: 2.4057, Accuracy: 1193/10000 (12%)
#
# Epoch:  55
# Loss=  tensor(2.1336)
#
# Test set, Epoch 56 , Average loss: 2.4108, Accuracy: 1236/10000 (12%)
#
# Epoch:  56
# Loss=  tensor(2.1301)
#
# Test set, Epoch 57 , Average loss: 2.3654, Accuracy: 1380/10000 (14%)
#
# Epoch:  57
# Loss=  tensor(2.1263)
#
# Test set, Epoch 58 , Average loss: 2.4056, Accuracy: 1149/10000 (11%)
#
# Epoch:  58
# Loss=  tensor(2.1217)
#
# Test set, Epoch 59 , Average loss: 2.4349, Accuracy: 1167/10000 (12%)
#
# Epoch:  59
# Loss=  tensor(2.1169)
#
# Test set, Epoch 60 , Average loss: 2.4714, Accuracy: 938/10000 (9%)
#
# Epoch:  60
# Loss=  tensor(2.1137)
#
# Test set, Epoch 61 , Average loss: 2.4496, Accuracy: 1086/10000 (11%)
#
# Epoch:  61
# Loss=  tensor(2.1105)
#
# Test set, Epoch 62 , Average loss: 2.4098, Accuracy: 1154/10000 (12%)
#
# Epoch:  62
# Loss=  tensor(2.1061)
#
# Test set, Epoch 63 , Average loss: 2.4720, Accuracy: 1009/10000 (10%)
#
# Epoch:  63
# Loss=  tensor(2.1023)
#
# Test set, Epoch 64 , Average loss: 2.4570, Accuracy: 1094/10000 (11%)
#
# Epoch:  64
# Loss=  tensor(2.0983)
#
# Test set, Epoch 65 , Average loss: 2.4770, Accuracy: 998/10000 (10%)
#
# Epoch:  65
# Loss=  tensor(2.0942)
#
# Test set, Epoch 66 , Average loss: 2.4931, Accuracy: 957/10000 (10%)
#
# Epoch:  66
# Loss=  tensor(2.0904)
#
# Test set, Epoch 67 , Average loss: 2.4637, Accuracy: 1121/10000 (11%)
#
# Epoch:  67
# Loss=  tensor(2.0865)
#
# Test set, Epoch 68 , Average loss: 2.4470, Accuracy: 1132/10000 (11%)
#
# Epoch:  68
# Loss=  tensor(2.0822)
#
# Test set, Epoch 69 , Average loss: 2.4926, Accuracy: 1014/10000 (10%)
#
# Epoch:  69
# Loss=  tensor(2.0797)
#
# Test set, Epoch 70 , Average loss: 2.4978, Accuracy: 1065/10000 (11%)
#
# Epoch:  70
# Loss=  tensor(2.0752)
#
# Test set, Epoch 71 , Average loss: 2.4635, Accuracy: 1059/10000 (11%)
#
# Epoch:  71
# Loss=  tensor(2.0721)
#
# Test set, Epoch 72 , Average loss: 2.4923, Accuracy: 1070/10000 (11%)
#
# Epoch:  72
# Loss=  tensor(2.0675)
#
# Test set, Epoch 73 , Average loss: 2.5222, Accuracy: 983/10000 (10%)
#
# Epoch:  73
# Loss=  tensor(2.0636)
#
# Test set, Epoch 74 , Average loss: 2.4932, Accuracy: 1078/10000 (11%)
#
# Epoch:  74
# Loss=  tensor(2.0601)
#
# Test set, Epoch 75 , Average loss: 2.4623, Accuracy: 1326/10000 (13%)
#
# Epoch:  75
# Loss=  tensor(2.0569)
#
# Test set, Epoch 76 , Average loss: 2.4720, Accuracy: 1105/10000 (11%)
#
# Epoch:  76
# Loss=  tensor(2.0530)
#
# Test set, Epoch 77 , Average loss: 2.4664, Accuracy: 1164/10000 (12%)
#
# Epoch:  77
# Loss=  tensor(2.0499)
#
# Test set, Epoch 78 , Average loss: 2.5195, Accuracy: 1084/10000 (11%)
#
# Epoch:  78
# Loss=  tensor(2.0465)
#
# Test set, Epoch 79 , Average loss: 2.5111, Accuracy: 1112/10000 (11%)
#
# Epoch:  79
# Loss=  tensor(2.0427)
#
# Test set, Epoch 80 , Average loss: 2.5137, Accuracy: 1089/10000 (11%)
#
# Epoch:  80
# Loss=  tensor(2.0394)
#
# Test set, Epoch 81 , Average loss: 2.5160, Accuracy: 1185/10000 (12%)
#
# Epoch:  81
# Loss=  tensor(2.0345)
#
# Test set, Epoch 82 , Average loss: 2.4989, Accuracy: 1242/10000 (12%)
#
# Epoch:  82
# Loss=  tensor(2.0319)
#
# Test set, Epoch 83 , Average loss: 2.5065, Accuracy: 1191/10000 (12%)
#
# Epoch:  83
# Loss=  tensor(2.0284)
#
# Test set, Epoch 84 , Average loss: 2.5321, Accuracy: 1117/10000 (11%)
#
# Epoch:  84
# Loss=  tensor(2.0239)
#
# Test set, Epoch 85 , Average loss: 2.5296, Accuracy: 1089/10000 (11%)
#
# Epoch:  85
# Loss=  tensor(2.0218)
#
# Test set, Epoch 86 , Average loss: 2.5110, Accuracy: 1181/10000 (12%)
#
# Epoch:  86
# Loss=  tensor(2.0184)
#
# Test set, Epoch 87 , Average loss: 2.5994, Accuracy: 926/10000 (9%)
#
# Epoch:  87
# Loss=  tensor(2.0147)
#
# Test set, Epoch 88 , Average loss: 2.5506, Accuracy: 1080/10000 (11%)
#
# Epoch:  88
# Loss=  tensor(2.0113)
#
# Test set, Epoch 89 , Average loss: 2.5613, Accuracy: 1034/10000 (10%)
#
# Epoch:  89
# Loss=  tensor(2.0074)
#
# Test set, Epoch 90 , Average loss: 2.5522, Accuracy: 1089/10000 (11%)
#
# Epoch:  90
# Loss=  tensor(2.0046)
#
# Test set, Epoch 91 , Average loss: 2.6065, Accuracy: 981/10000 (10%)
#
# Epoch:  91
# Loss=  tensor(2.0004)
#
# Test set, Epoch 92 , Average loss: 2.5787, Accuracy: 1035/10000 (10%)
#
# Epoch:  92
# Loss=  tensor(1.9970)
#
# Test set, Epoch 93 , Average loss: 2.5932, Accuracy: 986/10000 (10%)
#
# Epoch:  93
# Loss=  tensor(1.9929)
#
# Test set, Epoch 94 , Average loss: 2.5678, Accuracy: 1120/10000 (11%)
#
# Epoch:  94
# Loss=  tensor(1.9897)
#
# Test set, Epoch 95 , Average loss: 2.5692, Accuracy: 1118/10000 (11%)
#
# Epoch:  95
# Loss=  tensor(1.9869)
#
# Test set, Epoch 96 , Average loss: 2.5890, Accuracy: 1058/10000 (11%)
#
# Epoch:  96
# Loss=  tensor(1.9848)
#
# Test set, Epoch 97 , Average loss: 2.5905, Accuracy: 1087/10000 (11%)
#
# Epoch:  97
# Loss=  tensor(1.9817)
#
# Test set, Epoch 98 , Average loss: 2.5870, Accuracy: 986/10000 (10%)
#
# Epoch:  98
# Loss=  tensor(1.9776)
#
# Test set, Epoch 99 , Average loss: 2.5853, Accuracy: 1089/10000 (11%)
#
# Epoch:  99
# Loss=  tensor(1.9741)
#
# Test set, Epoch 100 , Average loss: 2.6306, Accuracy: 1070/10000 (11%)
#
# Epoch:  100
# Loss=  tensor(1.9701)

# %%
temp_1 = []
for i in m1_train_loss_arr:
    temp_1.append(i.data.numpy().tolist())
temp_2 = []
for i in m1_test_loss_arr:
    temp_2.append(i.data.numpy().tolist())

# %%
plt.figure(figsize=(10,10))
plt.plot(np.arange(0, 100, 1), temp_1, color = "r", alpha = 0.5)
plt.plot(np.arange(0, 100, 1), temp_2, color = "g", alpha = 0.5)
plt.title('Model Loss Comparision')
plt.legend(['Train Loss', 'Test Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()
